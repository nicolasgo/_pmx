# %% [markdown]
# # Nginx log analysis with pandas and matplotlib

# %% [markdown]
# By Jess Johnson [http://grokcode.com](http://grokcode.com)
#
# This notebook analyzes Nginx access logs in order to estimate the capacity needed to survive a traffic spike. I'm looking at access logs for [Author Alcove](http://authoralcove.com) which was hit by a big traffic spike when it spent around 24 hours at the top of [/r/books](http://reddit.com/r/books/). The site was hugged to death by reddit. Visitors experienced very slow load times, and many people couldn't access the site at all due to 50x errors. So let's estimate how much extra capacity would be needed to survive this spike.
#
# The source for this notebook is located on [github](https://github.com/grokcode/ipython-notebooks). See a mistake? Pull requests welcome.
#
# Thanks to Nikolay Koldunov for his [notebook on Apache log analysis](http://nbviewer.ipython.org/github/koldunovn/nk_public_notebooks/blob/master/Apache_log.ipynb), and thanks to my bro Aaron for the much needed optimism and server optimization tips while everything was on fire.
#
# OK let's get started.

# %% [markdown]
# ## Setup

# %%
# %pylab inline
file_name=_rootdir+'data/526142530854.pv'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Let's import the usual suspects.

# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# We will also use [apachelog](https://code.google.com/p/apachelog/), which is a module for parsing apache logs, but it works fine with nginx logs as long as we give it the right format string. You can install it with `pip install apachelog`.

# %%
import apachelog

# %% [markdown]
# ## Parsing the log

# %% [markdown]
# I started out by doing some command line preprocessing on the log in order to remove bots. I used `egrep -v` to filter out the bots that were hitting the site the most often. These were Googlebot, Bingbot, the New Relic uptime checker, Buidu spider, and a few others. A more careful approach would filter out everything on one of the known bot lists ([like this one](http://www.robotstxt.org/db.html)), but I'm going to play it a bit fast and loose.
#
# First of all let's get a sample line out of the `access.log` and try to parse it. Here is a description of the codes in the log format we are working with:
#
#     %h          - remote host (ie the client IP)
#     %l          - identity of the user determined by identd (not usually used since not reliable)
#     %u          - user name determined by HTTP authentication
#     %t          - time the server finished processing the request.
#     %r          - request line from the client. ("GET / HTTP/1.0")
#     %>s         - status code sent from the server to the client (200, 404 etc.)
#     %b          - size of the response to the client (in bytes)
#     %i      - Referer is the page that linked to this URL.
#     User-agent  - the browser identification string
#     %V          - the server name according to the UseCanonicalName setting

# %%
sample_string = '178.137.91.215 - - [21/Feb/2014:06:44:53 +0000] "GET /work/homepages-maths-year-6/ HTTP/1.0" \
200 10427 "http://authoralcove.com/work/homepages-maths-year-6/" "Opera/9.80 (Windows NT 6.1; WOW64; U; ru) \
Presto/2.10.289 Version/12.00" "-"'
nformat = r'%h %l %u %t \"%r\" %>s %b \"%i\" \"%{User-Agent}i\" \"%V\"'
p = apachelog.parser(nformat)
data = p.parse(sample_string)
data
# Out:
# {'%>s': '200',
#  '%V': '-',
#  '%b': '10427',
#  '%h': '178.137.91.215',
#  '%i': 'http://authoralcove.com/work/homepages-maths-year-6/',
#  '%l': '-',
#  '%r': 'GET /work/homepages-maths-year-6/ HTTP/1.0',
#  '%t': '[21/Feb/2014:06:44:53 +0000]',
#  '%u': '-',
#  '%{User-Agent}i': 'Opera/9.80 (Windows NT 6.1; WOW64; U; ru) Presto/2.10.289 Version/12.00'}

# %% [markdown]
# Now let's parse each line while preparing the access time so that pandas will be able to handle it.

# %%
from apachelog import ApacheLogParserError
log_list = []
with open(file_name) as f:
    for line in f.readlines():
        try:
            data = p.parse(line)
        except ApacheLogParserError:
            sys.stderr.write("Unable to parse %s" % line)
        data['%t'] = data['%t'][1:12]+' '+data['%t'][13:21]+' '+data['%t'][22:27]
        log_list.append(data)
# Out:
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:25 -0500] "GET /home/plugger HTTP/1.1" 200 4014 "-" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8156CA395DE005054E006A1 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:28 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3040 "http://mx.plugger.com/home/plugger" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8166CA395DE005054E006A2 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:33 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2759 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8166CA395DE005054E006A4 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:45 -0500] "POST /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8C06CA395DE005054E006B5 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:47 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2782 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8C06CA395DE005054E006B5 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:54 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3108 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B90B6CA395DE005054E006BE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:00 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2650 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9366CA395DE005054E006C4 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:07 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2706 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9626CA395DE005054E006CB "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:07 -0500] "POST /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9626CA395DE005054E006CA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:09 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3050 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9626CA395DE005054E006CB "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:14 -0500] "GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 200 2690 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9626CA395DE005054E006CE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:22 -0500] "POST /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A1876CA395DE005054E006DA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:24 -0500] "GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 200 2751 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A1876CA395DE005054E006DA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:26 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2976 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A1876CA395DE005054E006DC "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:29 -0500] "GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 200 2754 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A1876CA395DE005054E006DE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:55 -0500] "GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 200 2832 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2A06CA395DE005054E006FA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:39:57 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2997 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2A06CA395DE005054E006FB "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:00 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2666 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2A06CA395DE005054E006FD "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:14 -0500] "POST /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AEE46CA395DE005054E0070D "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:15 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2714 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AEE46CA395DE005054E0070E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:17 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2996 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AEE46CA395DE005054E0070F "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:21 -0500] "GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 200 2681 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AF1C6CA395DE005054E00712 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:25 -0500] "POST /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AF1C6CA395DE005054E00715 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:26 -0500] "GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 200 2742 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AF1C6CA395DE005054E00719 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:29 -0500] "GET /friends/ HTTP/1.1" 200 3546 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AF1C6CA395DE005054E0071A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:34 -0500] "GET /friends/requests/ HTTP/1.1" 200 3182 "http://mx.plugger.com/friends/" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AF1C6CA395DE005054E0071E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:35 -0500] "GET /profile/22325006/activities HTTP/1.1" 200 3745 "http://mx.plugger.com/friends/" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AFD46CA395DE005054E00723 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:35 -0500] "GET /profile/22325006 HTTP/1.1" 303 566 "http://mx.plugger.com/friends/" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213AFD46CA395DE005054E00722 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:42 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2330 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B0126CA395DE005054E0072A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:47 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2898 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B0126CA395DE005054E0072A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:40:52 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2642 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B0126CA395DE005054E00731 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:15 -0500] "POST /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1676CA395DE005054E0074B "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:16 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2721 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1676CA395DE005054E0074B "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:18 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2945 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1676CA395DE005054E0074C "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:22 -0500] "GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 200 2775 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1916CA395DE005054E0074F "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:28 -0500] "GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 200 2819 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1E46CA395DE005054E00757 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:28 -0500] "POST /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1E46CA395DE005054E00757 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:30 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2932 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B1E46CA395DE005054E00758 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:32 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2650 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B2046CA395DE005054E0075B "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:42 -0500] "POST /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B27C6CA395DE005054E00766 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:43 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2716 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B27C6CA395DE005054E00766 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:46 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2919 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B27C6CA395DE005054E00767 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:47 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2920 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B2A76CA395DE005054E0076A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:41:51 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2679 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B2A96CA395DE005054E0076B "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:42:32 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2783 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4186CA395DE005054E00797 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:42:34 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3070 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4186CA395DE005054E00798 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:42:39 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2603 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4186CA395DE005054E0079A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:42:54 -0500] "POST /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4F56CA395DE005054E007AD "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:42:57 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2668 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4F56CA395DE005054E007AE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:42:59 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3095 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4F56CA395DE005054E007B1 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:03 -0500] "GET /upload/browse/ HTTP/1.1" 200 1618 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4F56CA395DE005054E007B3 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:08 -0500] "GET /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1" 200 2723 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B4F56CA395DE005054E007B7 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:18 -0500] "GET /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1" 200 2779 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B5F56CA395DE005054E007C6 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:18 -0500] "POST /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B5F56CA395DE005054E007C5 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:20 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3022 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B5F56CA395DE005054E007C6 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:26 -0500] "GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 200 2722 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B6246CA395DE005054E007C9 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:37 -0500] "POST /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B6A16CA395DE005054E007D9 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:39 -0500] "GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 200 2786 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B6A16CA395DE005054E007D9 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:41 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2987 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B6A16CA395DE005054E007DB "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:43:44 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2718 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B6A16CA395DE005054E007DD "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:02 -0500] "POST /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B7956CA395DE005054E007F2 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:03 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2792 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B7956CA395DE005054E007F2 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:05 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2988 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B7956CA395DE005054E007F3 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:11 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2602 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B7956CA395DE005054E007F6 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:25 -0500] "POST /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8AF6CA395DE005054E00808 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:27 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2684 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8AF6CA395DE005054E00809 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:30 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3011 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8AF6CA395DE005054E0080B "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:33 -0500] "GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 200 2775 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B8AF6CA395DE005054E0080E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:42 -0500] "GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 200 2836 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9556CA395DE005054E0081A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:42 -0500] "POST /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9556CA395DE005054E00819 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:44 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2996 "http://mx.plugger.com/conversaciones/1d428c0b116804c32b611c863cff66c6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9556CA395DE005054E0081A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:44:47 -0500] "GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 200 2679 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213B9556CA395DE005054E0081D "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:03 -0500] "POST /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A19E6CA395DE005054E0082E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:04 -0500] "GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 200 2755 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A19E6CA395DE005054E0082F "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:06 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2920 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A19E6CA395DE005054E00830 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:09 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2704 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A19E6CA395DE005054E00832 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:30 -0500] "POST /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2B66CA395DE005054E0084A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:31 -0500] "GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1" 200 2764 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2B66CA395DE005054E0084A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:33 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2939 "http://mx.plugger.com/conversaciones/b21cd7b79c0d079a92db4486e95fc2d5" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2B66CA395DE005054E0084B "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:39 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2647 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A2E76CA395DE005054E0084E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:45 -0500] "POST /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3436CA395DE005054E00858 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:48 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2713 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3436CA395DE005054E00859 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:50 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2954 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3436CA395DE005054E0085C "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:45:53 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2668 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3436CA395DE005054E0085F "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:00 -0500] "POST /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3DB6CA395DE005054E00868 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:01 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2727 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3DB6CA395DE005054E00868 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:04 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2896 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3DB6CA395DE005054E00869 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:05 -0500] "GET /home/plugger HTTP/1.1" 200 3964 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A3DB6CA395DE005054E0086C "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:11 -0500] "GET /mymedia/content/76957445 HTTP/1.1" 303 576 "http://mx.plugger.com/home/plugger" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A4166CA395DE005054E0086F "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:12 -0500] "GET /profile/22210442/info?private_content HTTP/1.1" 200 2094 "http://mx.plugger.com/home/plugger" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A4166CA395DE005054E00873 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:22 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2980 "http://mx.plugger.com/home/plugger" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A4A76CA395DE005054E0087E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:27 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2641 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A4AA6CA395DE005054E0087F "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:50 -0500] "POST /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A5B96CA395DE005054E00899 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:52 -0500] "GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1" 200 2724 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A5B96CA395DE005054E0089A "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:54 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3103 "http://mx.plugger.com/conversaciones/08ba535fae7c22ebdb6e23185ceefbec" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A5B96CA395DE005054E0089C "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:46:59 -0500] "GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 200 2741 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A5B96CA395DE005054E0089E "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:06 -0500] "POST /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A6896CA395DE005054E008AA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:09 -0500] "GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1" 200 2792 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A6896CA395DE005054E008AA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:11 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3056 "http://mx.plugger.com/conversaciones/94f4fa1bf6054302db63cab68a39bf7e" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A6896CA395DE005054E008AD "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:14 -0500] "GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 200 2706 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A6D56CA395DE005054E008B0 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:26 -0500] "POST /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A76D6CA395DE005054E008BD "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:27 -0500] "GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1" 200 2772 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A76D6CA395DE005054E008BE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:28 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 2972 "http://mx.plugger.com/conversaciones/838f14e41b7d8b7cf8f70fd193a74735" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A76D6CA395DE005054E008BF "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:31 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2660 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A76D6CA395DE005054E008C1 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:37 -0500] "POST /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A7F66CA395DE005054E008C9 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:38 -0500] "GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1" 200 2723 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A7F66CA395DE005054E008C9 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:41 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3005 "http://mx.plugger.com/conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A7F66CA395DE005054E008CA "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:45 -0500] "GET /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1" 200 2738 "http://mx.plugger.com/profile/14119369/inbox" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A7F66CA395DE005054E008CE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:47:59 -0500] "POST /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1" 303 586 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A8A96CA395DE005054E008DE "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:48:00 -0500] "GET /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1" 200 2803 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A8A96CA395DE005054E008DF "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:48:02 -0500] "GET /profile/25085808 HTTP/1.1" 303 566 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A8A96CA395DE005054E008DF "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:48:03 -0500] "GET /profile/25085808/activities HTTP/1.1" 200 3759 "http://mx.plugger.com/conversaciones/b3e3f6e478c5d1fdb63b72b391462623" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A8A96CA395DE005054E008E2 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:48:05 -0500] "GET /profile/25085808/media HTTP/1.1" 200 2771 "http://mx.plugger.com/profile/25085808/activities" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A8A96CA395DE005054E008E3 "-"
# Unable to parse 189.254.162.19 189.254.162.19 - [14/Feb/2015:21:48:09 -0500] "GET /mymedia/content/76545412 HTTP/1.1" 200 2710 "http://mx.plugger.com/profile/25085808/media" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" 526142530854 BDFEA213A8A96CA395DE005054E008E5 "-"
# ...
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:02:33:32 -0500] "GET /profile/7812727/media?page=4&ajax HTTP/1.1" 200 1377 "http://mx.plugger.com/profile/7812727/media?page=2" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BD1406CA395DD005054E19D4A "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:02:33:35 -0500] "GET /mymedia/content/69824734 HTTP/1.1" 200 3312 "http://mx.plugger.com/profile/7812727/media?page=2" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BD1406CA395DD005054E19D4C "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:02:33:39 -0500] "GET /profile/7812727/media?page=3&ajax HTTP/1.1" 200 1362 "http://mx.plugger.com/profile/7812727/media?page=2" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BD1406CA395DD005054E19D50 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:02:33:41 -0500] "GET /profile/7812727/media?page=4&ajax HTTP/1.1" 200 1375 "http://mx.plugger.com/profile/7812727/media?page=2" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BD1696CA395DD005054E19D54 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:02:33:44 -0500] "GET /profile/7812727/media?page=5&ajax HTTP/1.1" 200 1370 "http://mx.plugger.com/profile/7812727/media?page=2" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BD1406CA395DD005054E19D56 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:02:33:48 -0500] "GET /mymedia/content/68903892 HTTP/1.1" 200 6008 "http://mx.plugger.com/profile/7812727/media?page=2" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BD1406CA395DD005054E19D58 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:28:33 -0500] "GET / HTTP/1.1" 303 551 "-" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA26D6CA395DE005054E1AA31 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:28:34 -0500] "GET /home/plugger HTTP/1.1" 200 5331 "-" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA26D6CA395DE005054E1AA31 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:29:03 -0500] "GET /friends/ HTTP/1.1" 200 3638 "http://mx.plugger.com/home/plugger" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA5326CA395DE005054E1AA4E "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:29:28 -0500] "GET /friends/requests/ HTTP/1.1" 200 3184 "http://mx.plugger.com/friends/" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA7D46CA395DE005054E1AA66 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:29:37 -0500] "GET /profile/22325006 HTTP/1.1" 303 566 "http://mx.plugger.com/friends/" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA7F36CA395DE005054E1AA71 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:29:40 -0500] "GET /profile/22325006/activities HTTP/1.1" 200 3838 "http://mx.plugger.com/friends/" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA7F36CA395DE005054E1AA71 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:29:57 -0500] "GET /activities/show/?&plugger=589367960&back=%2Fprofile%2F22325006%2Factivities%2F HTTP/1.1" 200 3136 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAD286CA395DE005054E1AA85 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:30:35 -0500] "GET /activities/show/?&plugger=588413413&back=%2Fprofile%2F22325006%2Factivities%2F HTTP/1.1" 200 2749 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB25D6CA395DE005054E1AAA6 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:31:38 -0500] "GET /activities/show/?&plugger=587921754&back=%2Fprofile%2F22325006%2Factivities%2F HTTP/1.1" 200 2454 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAEF56CA395DE005054E1AAE9 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:31:41 -0500] "GET /activities/show/?&plugger=587434260&back=%2Fprofile%2F22325006%2Factivities%2F HTTP/1.1" 200 2665 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAEF56CA395DE005054E1AAEA "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:32:06 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2299 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAF686CA395DE005054E1AB05 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:32:12 -0500] "GET /activities/show/?&plugger=587395616&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D2 HTTP/1.1" 200 2941 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAF8E6CA395DE005054E1AB0C "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:33:14 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2296 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA6F26CA395DE005054E1AB4A "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:33:25 -0500] "GET /activities/show/?&plugger=587395616&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D2 HTTP/1.1" 200 2931 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA70F6CA395DE005054E1AB55 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:33:29 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2293 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA7106CA395DE005054E1AB55 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:33:44 -0500] "GET /activities/show/?&plugger=586573769&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D2 HTTP/1.1" 200 3565 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA7536CA395DE005054E1AB68 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:35:49 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2289 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA8EE6CA395DE005054E1ABE5 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:36:08 -0500] "GET /activities/show/?&plugger=586550355&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D2 HTTP/1.1" 200 3747 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BADB26CA395DE005054E1ABF8 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:36:26 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2298 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA96F6CA395DE005054E1AC09 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:36:29 -0500] "GET /activities/show/?&plugger=586496696&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D2 HTTP/1.1" 200 3281 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA9706CA395DE005054E1AC0A "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:36:46 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2297 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA8FD6CA395DE005054E1AC1E "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:37:00 -0500] "GET /activities/show/?&plugger=583508392&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D2 HTTP/1.1" 200 2780 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA9506CA395DE005054E1AC2C "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:38:25 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2301 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAFA76CA395DE005054E1AC81 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:38:42 -0500] "GET /profile/22325006/activities?page=3&ajax HTTP/1.1" 200 2244 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA1246CA395DE005054E1AC91 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:38:51 -0500] "GET /activities/show/?&plugger=583394769&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D3 HTTP/1.1" 200 5166 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BA14D6CA395DE005054E1AC9B "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:39:08 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2303 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB0426CA395DE005054E1ACAB "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:39:14 -0500] "GET /profile/22325006/activities?page=3&ajax HTTP/1.1" 200 2242 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB0606CA395DE005054E1ACB2 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:39:29 -0500] "GET /activities/show/?&plugger=581525774&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D3 HTTP/1.1" 200 5064 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB0826CA395DE005054E1ACC1 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:41:52 -0500] "GET /profile/22325006/activities?page=3&ajax HTTP/1.1" 200 2249 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAE236CA395DE005054E1AD4D "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:42:06 -0500] "GET /activities/show/?&plugger=580467013&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D3 HTTP/1.1" 200 4449 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BAE816CA395DE005054E1AD5E "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:42:46 -0500] "GET /profile/22325006/activities?page=2&ajax HTTP/1.1" 200 2300 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB14D6CA395DE005054E1AD86 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:42:50 -0500] "GET /profile/22325006/activities?page=3&ajax HTTP/1.1" 200 2244 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB14D6CA395DE005054E1AD87 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:43:01 -0500] "GET /profile/22325006/activities?page=4&ajax HTTP/1.1" 200 2047 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB1866CA395DE005054E1AD95 "-"
# Unable to parse 201.144.174.11 201.144.174.11 - [16/Feb/2015:03:43:09 -0500] "GET /activities/show/?&plugger=580266161&back=%2Fprofile%2F22325006%2Factivities%2F%3Fpage%3D4 HTTP/1.1" 200 2725 "http://mx.plugger.com/profile/22325006/activities" "Mozilla/5.0 (Linux; Android 4.4.2; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.141 Mobile Safari/537.36" 526142530854 C990AE0BB1A06CA395DE005054E1AD9D "-"

# %% [markdown]
# Loading into pandas.

# %%
from pandas import Series, DataFrame, Panel
df = DataFrame(log_list)
df[0:2]
# Out:
#    %>s %V     %b              %h  \
# 0  200  -  10427  178.137.91.215
# 1  200  -   7507    202.46.54.40
#
#                                                   %i %l  \
# 0  http://authoralcove.com/work/homepages-maths-y...  -
# 1                                                  -  -
#
#                                            %r                          %t %u  \
# 0  GET /work/homepages-maths-year-6/ HTTP/1.0  21/Feb/2014 06:44:53 +0000  -
# 1                              GET / HTTP/1.1  21/Feb/2014 06:53:47 +0000  -
#
#                                       %{User-Agent}i
# 0  Opera/9.80 (Windows NT 6.1; WOW64; U; ru) Pres...
# 1  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
#
# [2 rows x 10 columns]

# %% [markdown]
# Now lets clean up the pandas dataframe a bit by deleting some columns we aren't interested in and renaming the remaining columns.

# %%
del df['%V']
del df['%h']
del df['%i']
del df['%l']
del df['%u']
del df['%{User-Agent}i']
df[0:2]
# Out:
#    %>s     %b                                          %r  \
# 0  200  10427  GET /work/homepages-maths-year-6/ HTTP/1.0
# 1  200   7507                              GET / HTTP/1.1
#
#                            %t
# 0  21/Feb/2014 06:44:53 +0000
# 1  21/Feb/2014 06:53:47 +0000
#
# [2 rows x 4 columns]

# %%
df = df.rename(columns={'%>s': 'Status', '%b':'b', 
                        '%r':'Request', '%t': 'Time'})
df[0:2]
# Out:
#   Status      b                                     Request  \
# 0    200  10427  GET /work/homepages-maths-year-6/ HTTP/1.0
# 1    200   7507                              GET / HTTP/1.1
#
#                          Time
# 0  21/Feb/2014 06:44:53 +0000
# 1  21/Feb/2014 06:53:47 +0000
#
# [2 rows x 4 columns]

# %% [markdown]
# Massage the data a bit more so that the access time is a `datetime`, status is an `int`, and the response size is in MB, with missing data represented as `NaN`, not `-`.

# %%
df.index = pd.to_datetime(df.pop('Time'))

# %%
df['Status'] = df['Status'].astype('int')

# %%
def dash2nan(x):
    if x == '-':
        x = np.nan
    else:
        x = float(x)/1048576.
    
    return x
df['b'] = df['b'].apply(dash2nan)

# %% [markdown]
# ## Analysis

# %% [markdown]
# Let's graph the data to visualize what is happening.
#
# First let's increase the graph size.

# %%
from pylab import *
rcParams['figure.figsize'] = 10, 5 # width, height in inches

# %% [markdown]
# Now let's graph the requests hitting the web server. `10t` will use a 10 minute interval size, so each point on the graph shows the number of requestes in a 10 minute window.

# %%
df_s = df['Status'].resample('10t', how='count')
df_s.plot()

# %% [markdown]
# Above we see that we were peaking at around 4500 requests every 10 minutes, or about 450 requests a minute. There was a quick ramp up as the site climbed to the top position on /r/books, then a drop off overnight (for US timezones), another peak the next day as people woke up, and then a decline as the site fell back down the /r/books page.
#
# Let's see how the server held up by looking at some response codes.

# %%
df['Status'].value_counts()
# Out:
# 200    413236
# 502     39769
# 499     37443
# 304     29777
# 302      9467
# 404      8171
# 504      8105
# 301      1743
# 401       677
# 403       262
# 500       171
# 206        51
# 444        40
# 400        20
# 408         4
# 405         1
# dtype: int64

# %% [markdown]
# There are quite a few 500 errors here. 499 errors are also bad news because it means that the client closed the connection before the page could be served. These are almost certainly because the site wasn't responding in a reasonable timeframe.
#
# Let's graph the response codes.

# %%
grouped_status = df.groupby('Status')
grouped_status.size().plot(kind='bar')

# %% [markdown]
# OK that doesn't look too bad. The vast majority of requests were served a 200 (OK) response.
#
# Let's graph the most common response codes over time, with a sample timespan of 1 hour.

# %%
t_span = '60t'
df_200 = df['Status'][df['Status'] == 200].resample(t_span, how='count')
df_502 = df['Status'][df['Status'] == 502].resample(t_span, how='count')
df_499 = df['Status'][df['Status'] == 499].resample(t_span, how='count')
df_304 = df['Status'][df['Status'] == 304].resample(t_span, how='count')
df_302 = df['Status'][df['Status'] == 302].resample(t_span, how='count')
df_404 = df['Status'][df['Status'] == 404].resample(t_span, how='count')
df_504 = df['Status'][df['Status'] == 504].resample(t_span, how='count')
df_301 = df['Status'][df['Status'] == 301].resample(t_span, how='count')


status_df = DataFrame({'OK': df_200, 
                       'Bad Gateway': df_502, 
                       'Client Closed': df_499, 
                       'Not Modified': df_304, 
                       'Found': df_302, 
                       'Not Found': df_404,
                       'Gateway Timeout': df_504,
                       'Moved Permenantely': df_301})

# %%
status_df.fillna(0, inplace=True)
status_df[0:5]
# Out:
#                      Bad Gateway  Client Closed  Found  Gateway Timeout  \
# Time
# 2014-02-21 06:00:00            0              0      0                0
# 2014-02-21 07:00:00            0              0      3                0
# 2014-02-21 08:00:00            0              0      0                0
# 2014-02-21 09:00:00            0              0      0                0
# 2014-02-21 10:00:00            0              6      0                3
#
#                      Moved Permenantely  Not Found  Not Modified  OK
# Time
# 2014-02-21 06:00:00                   0          0             0   3
# 2014-02-21 07:00:00                   0          4             1  29
# 2014-02-21 08:00:00                   0          0             0   2
# 2014-02-21 09:00:00                   0          2             0   3
# 2014-02-21 10:00:00                   0          0             0   2
#
# [5 rows x 8 columns]

# %%
status_df.plot()
legend()

# %% [markdown]
# This doesn't look too bad either, but it's hard to make sense of what is going on with so many different response codes. Let's group them into success (web server handled it as expected) and failure (web server error or client closed request).
#
#     200    413236    Success    OK
#     502     39769    Failure    Bad Gateway
#     499     37443    Failure    Client closed request
#     304     29777    Success    Not modified
#     302      9467    Success    Found
#     404      8171    Success    Not Found
#     504      8105    Failure    Gateway timeout
#     301      1743    Success    Moved permanently
#     401       677    Success    Unauthorized
#     403       262    Success    Forbidden
#     500       171    Failure    Internal server error
#     206        51    Success    Partial content
#     444        40    Failure?   No response
#     400        20    Success?   Bad request
#     408         4    Success?   Request timeout
#     405         1    Success?   Method not allowed

# %%
success_df = df[df['Status'].isin([200, 304, 302, 404, 301, 401, 403, 206, 444, 400, 408, 405])].resample(t_span, how='count')
fail_df = df[df['Status'].isin([502, 499, 504, 500, 444])].resample(t_span, how='count')
success_df.plot(label="Success")
fail_df.plot(label="Failure")
legend()

# %% [markdown]
# Those are the requests served by nginx, so it includes both static files like css and javascript and dynamic content that was passed off to the Django app running on uwsgi. Let's filter out the static files and see how uwsgi did. In this case almost all of the static files have `/static/` in the path with a few exceptions such as the `favicon.ico`.

# %%
dynamic_df = df[df['Request'].str.contains(r'^GET /(static|favicon.ico)') == False]
dynamic_df[0:10]
# Out:
#                      Status         b  \
# Time
# 2014-02-21 06:44:53     200  0.009944
# 2014-02-21 06:53:47     200  0.007159
# 2014-02-21 06:54:22     200  0.007159
# 2014-02-21 07:01:28     200  0.002501
# 2014-02-21 07:02:11     200  0.004643
# 2014-02-21 07:03:06     302  0.000000
# 2014-02-21 07:03:07     200  0.003963
# 2014-02-21 07:03:41     200  0.001887
# 2014-02-21 07:03:48     200  0.002122
# 2014-02-21 07:03:55     200  0.002145
#
#                                                                Request
# Time
# 2014-02-21 06:44:53         GET /work/homepages-maths-year-6/ HTTP/1.0
# 2014-02-21 06:53:47                                     GET / HTTP/1.1
# 2014-02-21 06:54:22                                     GET / HTTP/1.1
# 2014-02-21 07:01:28                                     GET / HTTP/1.1
# 2014-02-21 07:02:11             GET /accounts/create-account/ HTTP/1.1
# 2014-02-21 07:03:06            POST /accounts/create-account/ HTTP/1.1
# 2014-02-21 07:03:07             GET /work/lists/most-popular/ HTTP/1.1
# 2014-02-21 07:03:41  GET /work/lists/most-popular/?page=2&querystri...
# 2014-02-21 07:03:48  GET /work/lists/most-popular/?page=3&querystri...
# 2014-02-21 07:03:55  GET /work/lists/most-popular/?page=4&querystri...
#
# [10 rows x 3 columns]

# %%
success_df = dynamic_df[dynamic_df['Status'].isin([200, 304, 302, 301, 401])].resample(t_span, how='count')
fail_df = dynamic_df[dynamic_df['Status'].isin([502, 499, 504, 500])].resample(t_span, how='count')
success_df.plot(label="Success", color="g")
fail_df.plot(label="Failure", color="r")
legend()

# %% [markdown]
# Ouch! So during the initial peak, uwsgi is failing more often than not. Let's look at the same data in a stacked bar chart.

# %%
responses_df = DataFrame({'Success': success_df, 
                          'Failure': fail_df,
                          })
responses_df.plot(kind="bar", stacked=True, xticks=(), colors=("r", "g",))

# %% [markdown]
# It looks like about 2,000 requests / hour is all uwsgi can handle before it starts to throw errors. That is only about 1 request every two seconds so that is a pretty big problem.
#
# We needed to handle 10,000 requests / hour, but we were only able to handle 2,000 requests / hour. So it looks like we would need roughly 5x the capacity to handle a spike of this size. This is a little bit misleading though because many visitors abandoned the site after hitting 50X errors and long page loads.
#
# Here is a view of the same traffic spike from Google Analytics.
#
# ![Google Analytics Pageviews vs. Pages per Visit](files/data/google-analytics.png)
#
# During the spike, pages per visit were roughly half of what they normally were, so let's double the 5x estimate and plan for 10x the capacity to handle this load.

# %% [markdown]
# ## Solutions

# %% [markdown]
# One solution is to upgrade the server running uwsgi and use ten times the number of workers to handle requests, but let's see if we can be a bit smarter.
#
# Another solution is to optimize the web app by shortening long-running requests, but I have already picked most of the low hanging fruit there.
#
# Let's investigate to see if there are any opportunities to prevent requests from hitting uwsgi in the first place.
#
# First let's get a count pages with the most requests.

# %%
dynamic_df['Request'].value_counts().head(40)
# Out:
# GET / HTTP/1.1                                                  48707
# GET /work/lists/most-popular/ HTTP/1.1                          19818
# GET /accounts/create-account/ HTTP/1.1                          10301
# GET /apple-touch-icon.png HTTP/1.1                               9591
# POST /accounts/create-account/ HTTP/1.1                          6537
# GET /work/lists/most-popular/?page=2&querystring_key=page HTTP/1.1     6335
# GET /work/lists/highest-rated/ HTTP/1.1                          5819
# GET /accounts/login/ HTTP/1.1                                    3502
# GET /work/lists/most-popular/?page=3&querystring_key=page HTTP/1.1     3055
# GET /work/lists/most-popular/?page=4&querystring_key=page HTTP/1.1     2208
# POST /accounts/login/ HTTP/1.1                                   2071
# GET /work/lists/most-popular/?page=5&querystring_key=page HTTP/1.1     1699
# POST /work/rate/195559/ HTTP/1.1                                 1462
# POST /work/rate/182662/ HTTP/1.1                                 1450
# POST /work/rate/179080/ HTTP/1.1                                 1429
# POST /work/rate/172160/ HTTP/1.1                                 1378
# GET /work/lists/most-popular/?page=6&querystring_key=page HTTP/1.1     1376
# POST /work/rate/172203/ HTTP/1.1                                 1375
# POST /work/rate/179079/ HTTP/1.1                                 1313
# POST /work/rate/174370/ HTTP/1.1                                 1295
# GET /work/lists/highest-rated/?page=2&querystring_key=page HTTP/1.1     1294
# POST /work/rate/224637/ HTTP/1.1                                 1232
# GET /work/lists/most-popular/?page=7&querystring_key=page HTTP/1.1     1173
# GET /user/recommended/ HTTP/1.1                                  1085
# POST /work/rate/23173/ HTTP/1.1                                  1076
# POST /work/rate/172553/ HTTP/1.1                                 1068
# GET /accounts/edit-profile/ HTTP/1.1                             1045
# POST /work/rate/8697/ HTTP/1.1                                   1007
# GET /work/lists/most-popular/?page=8&querystring_key=page HTTP/1.1     1007
# POST /work/rate/217649/ HTTP/1.1                                  969
# POST /work/rate/172161/ HTTP/1.1                                  937
# POST /work/rate/25922/ HTTP/1.1                                   904
# GET /work/lists/most-popular/?page=9&querystring_key=page HTTP/1.1      892
# POST /work/rate/1724/ HTTP/1.1                                    848
# POST /work/rate/172335/ HTTP/1.1                                  796
# GET /work/lists/most-popular/?page=10&querystring_key=page HTTP/1.1      793
# GET /work/the-name-of-the-wind-kingkiller-chronicles-day-1/ HTTP/1.1      790
# GET /work/lists/most-popular/?utm_campaign=webapp&utm_medium=email&utm_source=Welcome+to+Author+Alcove HTTP/1.1      784
# GET /apple-touch-icon-precomposed.png HTTP/1.1                    768
# POST /work/rate/171563/ HTTP/1.1                                  762
# dtype: int64

# %% [markdown]
# There isn't much that can be done with the POST requests - they need to hit uwsgi so we can save new accounts or ratings in the database. So let's move on to the GET requests. There are two basic techniques for having nginx serve these pages. First, we could have uwsgi store the fully rendered page in memcached or similar, then have nginx try to pull the page from memcached and falling back to uwsgi if the page wasn't in the cache. The second idea is to have uwsgi create a static file, and then let nginx serve that if it exists. Unfortunately, in this case both of those solutions are problematic. It is beyond the scope of this notebook to go into details (hopefully I will have a separate blog post on that soon), but the gist is that for most of these pages, the content changes depending on who is viewing them, so they can't readily be cached at the page level.
#
# The biggest gain would be to make the homepage static. The homepage will redirect to a user's recommended page if they are already logged in, but we could possibly detect logged in users with nginx via the http headers and only serve the static page to logged out visitors. Let's see what proportion of visitors who hit the homepage were logged in already.

# %%
dynamic_df[dynamic_df['Request'].str.contains('GET / HTTP/1.1')]['Status'].value_counts()
# Out:
# 200    19331
# 502    12559
# 499    10781
# 302     3053
# 504     2036
# 301      946
# 500        1
# dtype: int64

# %% [markdown]
# Of the visitors who were able to access the homepage, (19331 / (3053 + 946 + 19331)) * 100 = 83% were logged out. So that nginx configuration change would have saved a bit more than 40,000 requests.
#
# Out of how many total?

# %%
dynamic_df.count()
# Out:
# Status     307402
# b          307402
# Request    307402
# dtype: int64

# %% [markdown]
# So that change alone would offload 13% of uwsgi's request load to nginx. That's a good start.
#
# Another thing that jumps out is that `/apple-touch-icon.png` and `/apple-touch-icon-precomposed.png` don't actually exist have to be passed off to uwsgi before they 404. Setting up nginx to serve anything ending in `.png` will save some requests. Let's see if there are any other files like that.

# %%
dynamic_df[dynamic_df['Request'].str.contains(r'(png |xml |gif )')]['Request'].value_counts().head(10)
# Out:
# GET /apple-touch-icon.png HTTP/1.1                        9591
# GET /apple-touch-icon-precomposed.png HTTP/1.1             768
# GET /apple-touch-icon-120x120-precomposed.png HTTP/1.1     103
# GET /apple-touch-icon-120x120.png HTTP/1.1                  91
# GET /apple-touch-icon-152x152-precomposed.png HTTP/1.1      36
# GET /browserconfig.xml HTTP/1.1                             35
# GET /apple-touch-icon-152x152.png HTTP/1.1                  33
# GET /blog/images/logo3.png HTTP/1.1                         18
# GET /apple-touch-icon-76x76-precomposed.png HTTP/1.1        14
# GET /blog/atom.xml HTTP/1.1                                 13
# dtype: int64

# %% [markdown]
# Let's see how many requests that will save.

# %%
dynamic_df[dynamic_df['Request'].str.contains(r'(png |xml |gif )')].count()
# Out:
# Status     10870
# b          10870
# Request    10870
# dtype: int64

# %% [markdown]
# That is another 3.5% of requests.
#
# Between those two changes we will save 16.5% of requests from hitting uwsgi. It isn't enough to prevent the need for a server upgrade, but it does get us a bit closer.
