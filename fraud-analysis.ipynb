# %% [markdown]
# # Nginx log analysis

# %% [markdown]
# ## Setup

# %%
# %pylab inline
file_name=_rootdir+'data/fraud-worst/worst.log'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import apachelog

# %% [markdown]
# ## Parsing the log

# %%
sample_string = '189.254.162.19 189.254.162.19 - [14/Feb/2015:21:38:28 -0500] "GET /profile/14119369/inbox HTTP/1.1" 200 3040 \
"http://mx.plugger.com/home/plugger" "Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36" \
526142530854'# BDFEA213B8166CA395DE005054E006A2 "-"'
nformat1 = r'%h %l %u %t \"%r\" %>s %b \"%i\" \"%{User-Agent}i\" %{msisdn}b'
nformat2 = r'%h %l %u %t \"%r\" %>s %b \"%i\" \"%{User-Agent}i\" %{msisdn}b %{hexa}i \"%V\"'


p1 = apachelog.parser(nformat1)
p2 = apachelog.parser(nformat2)

data = p1.parse(sample_string)
data
# Out:
# {'%>s': '200',
#  '%b': '3040',
#  '%h': '189.254.162.19',
#  '%i': 'http://mx.plugger.com/home/plugger',
#  '%l': '189.254.162.19',
#  '%r': 'GET /profile/14119369/inbox HTTP/1.1',
#  '%t': '[14/Feb/2015:21:38:28 -0500]',
#  '%u': '-',
#  '%{User-Agent}i': 'Mozilla/5.0 (Linux; U; Android 4.4.2; es-sa; LG-D320 Build/KOT49I.V10a) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.1599.103 Mobile Safari/537.36',
#  '%{msisdn}b': '526142530854'}

# %% [markdown]
# Now let's parse each line while preparing the access time so that pandas will be able to handle it.

# %%
from apachelog import ApacheLogParserError
log_list = []
with open(file_name) as f:
    for line in f.readlines():
        try:
            data = p1.parse(line)
        except ApacheLogParserError:
            try:
                data = p2.parse(line)
            except ApacheLogParserError:
                sys.stderr.write("Unable to parse %s" % line)
                break
        data['%t'] = data['%t'][1:12]+' '+data['%t'][13:21]+' '+data['%t'][22:27]
        log_list.append(data)

# %% [markdown]
# Loading into pandas.

# %%
from pandas import Series, DataFrame, Panel
df = DataFrame(log_list)
df.head(2)
# Out:
#    %>s  \
# 0  200
# 1  200
#
#     %V  \
# 0  NaN
# 1  NaN
#
#      %b  \
# 0  2828
# 1  1822
#
#                %h  \
# 0   187.237.231.5
# 1  187.237.239.49
#
#                                                   %i  \
# 0  http://mx.plugger.com/conversaciones/9bfdc8ddf...
# 1                     http://mx.plugger.com/friends/
#
#                %l  \
# 0   187.237.231.5
# 1  187.237.239.49
#
#                                      %r  \
# 0  GET /profile/18203160/inbox HTTP/1.1
# 1    GET /friends/?page=5&ajax HTTP/1.1
#
#                            %t  \
# 0  01/Jan/2015 00:00:01 -0500
# 1  01/Jan/2015 00:00:04 -0500
#
#   %u  \
# 0  -
# 1  -
#
#                                       %{User-Agent}i  \
# 0  Mozilla/5.0 (compatible; MSIE 10.0; Windows Ph...
# 1  Mozilla/5.0 (Linux; U; Android 4.0.4; es-mx; S...
#
#   %{hexa}i  \
# 0      NaN
# 1      NaN
#
#      %{msisdn}b
# 0  524286816462
# 1  524281029119

# %% [markdown]
# Now lets clean up the pandas dataframe a bit by deleting some columns we aren't interested in and renaming the remaining columns.

# %%
try :
    del df['%V']
    del df['%h']
    del df['%i']
    del df['%l']
    del df['%u']
    del df['%{hexa}i']
    del df['%{User-Agent}i']

    df = df.rename(columns={'%>s': 'status', '%b':'b', 
                            '%r':'request', '%t': 'time', '%{msisdn}b': 'msisdn'})
except :
    pass

df['time']=pd.to_datetime(df['time'])
df['status'] = df['status'].astype('int')
df['b'] = df['b'].astype('int')

df.head(2)
# Out:
#    status  \
# 0     200
# 1     200
#
#       b  \
# 0  2828
# 1  1822
#
#                                 request  \
# 0  GET /profile/18203160/inbox HTTP/1.1
# 1    GET /friends/?page=5&ajax HTTP/1.1
#
#                  time  \
# 0 2015-01-01 05:00:01
# 1 2015-01-01 05:00:04
#
#          msisdn
# 0  524286816462
# 1  524281029119

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641922 entries, 0 to 641921
# Data columns (total 5 columns):
# status     641922 non-null int64
# b          641922 non-null int64
# request    641922 non-null object
# time       641922 non-null datetime64[ns]
# msisdn     641922 non-null object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 29.4+ MB

# %%
def dash2nan(x):
    if x == '-':
        x = np.nan
    else:
        x = float(x)/1048576.
    
    return x
df['b'] = df['b'].apply(dash2nan)

# %%
#df.set_index(['msisdn','status','time'], inplace=True)
df.head()
# Out:
#    status  \
# 0     200
# 1     200
# 2     200
# 3     303
# 4     200
#
#           b  \
# 0  0.002697
# 1  0.001738
# 2  0.002811
# 3  0.000537
# 4  0.002828
#
#                                              request  \
# 0               GET /profile/18203160/inbox HTTP/1.1
# 1                 GET /friends/?page=5&ajax HTTP/1.1
# 2  GET /mymedia/content/66330100?&back=%2Fprofile...
# 3  POST /mymedia/content/69351631/comment/add HTT...
# 4             GET /mymedia/content/69351631 HTTP/1.1
#
#                  time  \
# 0 2015-01-01 05:00:01
# 1 2015-01-01 05:00:04
# 2 2015-01-01 05:00:04
# 3 2015-01-01 05:00:04
# 4 2015-01-01 05:00:05
#
#          msisdn
# 0  524286816462
# 1  524281029119
# 2  526181593555
# 3  526142530854
# 4  526142530854

# %%
df.set_index(['time'],inplace=True)
df.head()
# Out:
#                      status  \
# time
# 2015-01-01 05:00:01     200
# 2015-01-01 05:00:04     200
# 2015-01-01 05:00:04     200
# 2015-01-01 05:00:04     303
# 2015-01-01 05:00:05     200
#
#                             b  \
# time
# 2015-01-01 05:00:01  0.002697
# 2015-01-01 05:00:04  0.001738
# 2015-01-01 05:00:04  0.002811
# 2015-01-01 05:00:04  0.000537
# 2015-01-01 05:00:05  0.002828
#
#                                                                request  \
# time
# 2015-01-01 05:00:01               GET /profile/18203160/inbox HTTP/1.1
# 2015-01-01 05:00:04                 GET /friends/?page=5&ajax HTTP/1.1
# 2015-01-01 05:00:04  GET /mymedia/content/66330100?&back=%2Fprofile...
# 2015-01-01 05:00:04  POST /mymedia/content/69351631/comment/add HTT...
# 2015-01-01 05:00:05             GET /mymedia/content/69351631 HTTP/1.1
#
#                            msisdn
# time
# 2015-01-01 05:00:01  524286816462
# 2015-01-01 05:00:04  524281029119
# 2015-01-01 05:00:04  526181593555
# 2015-01-01 05:00:04  526142530854
# 2015-01-01 05:00:05  526142530854

# %%
df_d=df[df.msisdn=='524286816462'].b.resample('1440t', how=['sum'])

# %%
df_d.head()
# Out:
#                   sum
# time
# 2014-12-31   4.544616
# 2015-01-01   8.888342
# 2015-01-02  16.550554
# 2015-01-03  15.251138
# 2015-01-04   6.683784

# %%
#sns.barplot(df_d.b['sum']) #df_d.head()
plt.plot(df_d)

# %% [markdown]
# ##

# %%
t=df.groupby(['msisdn'])#,'status'])
t#.resample('1440t')#['b']

# %%
parts = []

for k,v in t:
    x=[k,v['b'].sum()]
#    x=v[['T']].describe().T#[['mean','std']]
#    x['area'] = k
    parts.append(pd.DataFrame(x).T)

# %%
stats_per_msisdn = pd.concat(parts)
stats_per_msisdn.columns=['msisdn','mb']

# %%
stats_per_msisdn
# Out:
#          msisdn  \
# 0  522461274913
# 0  523318395534
# 0  523334561193
# 0  524281029119
# 0  524286816462
# 0  524451118258
# 0  524727212780
# 0  524921168213
# 0  526142530854
# 0  526181593555
# 0  526561451172
# 0  527351202563
# 0  527711867203
# 0  528112394174
# 0  528113827163
# 0  528119804914
# 0  528661595312
# 0  528711883608
# 0  528713361306
# 0  529721037999
#
#          mb
# 0   8.86417
# 0   60.9925
# 0  77.50556
# 0  97.16936
# 0  278.2273
# 0   84.6002
# 0  47.48493
# 0  66.75758
# 0  262.7614
# 0  142.9906
# 0  36.39305
# 0   54.1955
# 0  14.37345
# 0  58.78246
# 0  27.12914
# 0  283.4757
# 0  24.65897
# 0  55.07195
# 0  42.61797
# 0  18.27373

# %%
fn=_rootdir+'stats_per_msisdn.csv'
stats_per_msisdn.to_csv(fn)
# !head {fn}
# Out:
# ,msisdn,mb
# 0,522461274913,8.8641700744628906
# 0,523318395534,60.992496490478516
# 0,523334561193,77.505558967590332
# 0,524281029119,97.169364929199219
# 0,524286816462,278.22728252410889
# 0,524451118258,84.600201606750488
# 0,524727212780,47.48493480682373
# 0,524921168213,66.757584571838379
# 0,526142530854,262.76135540008545

# %% [markdown]
# ## Analysis

# %% [markdown]
# Let's graph the data to visualize what is happening.
#
# First let's increase the graph size.

# %%
from pylab import *
rcParams['figure.figsize'] = 10, 5 # width, height in inches

# %% [markdown]
# Now let's graph the requests hitting the web server. `20t` will use a 20 minute interval size, so each point on the graph shows the number of requestes in a 10 minute window.

# %%
df_s = df['Status'].resample('20t', how='count')
df_s.plot()

# %% [markdown]
# Above we see that we were peaking at around 4500 requests every 10 minutes, or about 450 requests a minute. There was a quick ramp up as the site climbed to the top position on /r/books, then a drop off overnight (for US timezones), another peak the next day as people woke up, and then a decline as the site fell back down the /r/books page.
#
# Let's see how the server held up by looking at some response codes.

# %%
df['Status'].value_counts()
# Out:
# 200    5430
# 303    1269
# 499      70
# 500       1
# 404       1
# dtype: int64

# %%
#df[df['Status'] == 200].b.sum()
df_daily=df['b'].resample('1440t', how='sum')
print df_daily
df_daily.plot()
# Out:
# Time
# 2015-02-14     4.892407
# 2015-02-15    10.137294
# 2015-02-16     0.577000
# Freq: 1440T, Name: b, dtype: float64

# %% [markdown]
# There are quite a few 500 errors here. 499 errors are also bad news because it means that the client closed the connection before the page could be served. These are almost certainly because the site wasn't responding in a reasonable timeframe.
#
# Let's graph the response codes.

# %%
grouped_status = df.groupby('Status')
grouped_status.size().plot(kind='bar')

# %% [markdown]
# OK that doesn't look too bad. The vast majority of requests were served a 200 (OK) response.
#
# Let's graph the most common response codes over time, with a sample timespan of 1 hour.

# %%
t_span = '60t' #1440 = per day 60t= per hour
df_200 = df['Status'][df['Status'] == 200].resample(t_span, how='count')
df_502 = df['Status'][df['Status'] == 502].resample(t_span, how='count')
df_499 = df['Status'][df['Status'] == 499].resample(t_span, how='count')
df_304 = df['Status'][df['Status'] == 304].resample(t_span, how='count')
df_302 = df['Status'][df['Status'] == 302].resample(t_span, how='count')
df_404 = df['Status'][df['Status'] == 404].resample(t_span, how='count')
df_504 = df['Status'][df['Status'] == 504].resample(t_span, how='count')
df_301 = df['Status'][df['Status'] == 301].resample(t_span, how='count')


status_df = DataFrame({'OK': df_200, 
                       'Bad Gateway': df_502, 
                       'Client Closed': df_499, 
                       'Not Modified': df_304, 
                       'Found': df_302, 
                       'Not Found': df_404,
                       'Gateway Timeout': df_504,
                       'Moved Permenantely': df_301})

# %%
status_df.fillna(0, inplace=True)
status_df
# Out:
#                      Bad Gateway  \
# Time
# 2015-02-14 18:00:00            0
# 2015-02-14 19:00:00            0
# 2015-02-14 20:00:00            0
# 2015-02-14 21:00:00            0
# 2015-02-14 22:00:00            0
# 2015-02-14 23:00:00            0
# 2015-02-15 00:00:00            0
# 2015-02-15 01:00:00            0
# 2015-02-15 02:00:00            0
# 2015-02-15 03:00:00            0
# 2015-02-15 04:00:00            0
# 2015-02-15 05:00:00            0
# 2015-02-15 06:00:00            0
# 2015-02-15 07:00:00            0
# 2015-02-15 08:00:00            0
# 2015-02-15 09:00:00            0
# 2015-02-15 10:00:00            0
# 2015-02-15 11:00:00            0
# 2015-02-15 12:00:00            0
# 2015-02-15 13:00:00            0
# 2015-02-15 14:00:00            0
# 2015-02-15 15:00:00            0
# 2015-02-15 16:00:00            0
# 2015-02-15 17:00:00            0
# 2015-02-15 18:00:00            0
# 2015-02-15 19:00:00            0
# 2015-02-15 20:00:00            0
# 2015-02-15 21:00:00            0
# 2015-02-15 22:00:00            0
# 2015-02-15 23:00:00            0
# 2015-02-16 00:00:00            0
# 2015-02-16 01:00:00            0
# 2015-02-16 02:00:00            0
# 2015-02-16 03:00:00            0
# 2015-02-16 04:00:00            0
# 2015-02-15 06:00:00    0
# 2015-02-15 07:00:00  234
# 2015-02-15 08:00:00  233
# 2015-02-15 09:00:00  127
# 2015-02-15 10:00:00  272
# 2015-02-15 11:00:00  168
# 2015-02-15 12:00:00  144
# 2015-02-15 13:00:00  246
# 2015-02-15 14:00:00  289
# 2015-02-15 15:00:00  197
# 2015-02-15 16:00:00    0
# 2015-02-15 17:00:00    0
# 2015-02-15 18:00:00    0
# 2015-02-15 19:00:00    0
# 2015-02-15 20:00:00    0
# 2015-02-15 21:00:00    0
# 2015-02-15 22:00:00    0
# 2015-02-15 23:00:00    0
# 2015-02-16 00:00:00    0
# 2015-02-16 01:00:00    0
# 2015-02-16 02:00:00   34
# 2015-02-16 03:00:00   35
# 2015-02-16 04:00:00   50
# 2015-02-16 05:00:00   55
# 2015-02-16 06:00:00    3
# 2015-02-16 07:00:00   27
# 2015-02-16 08:00:00   32

# %%
status_df.plot()
legend()

# %% [markdown]
# This doesn't look too bad either, but it's hard to make sense of what is going on with so many different response codes. Let's group them into success (web server handled it as expected) and failure (web server error or client closed request).
#
#     200    413236    Success    OK
#     502     39769    Failure    Bad Gateway
#     499     37443    Failure    Client closed request
#     304     29777    Success    Not modified
#     302      9467    Success    Found
#     404      8171    Success    Not Found
#     504      8105    Failure    Gateway timeout
#     301      1743    Success    Moved permanently
#     401       677    Success    Unauthorized
#     403       262    Success    Forbidden
#     500       171    Failure    Internal server error
#     206        51    Success    Partial content
#     444        40    Failure?   No response
#     400        20    Success?   Bad request
#     408         4    Success?   Request timeout
#     405         1    Success?   Method not allowed

# %%
success_df = df[df['Status'].isin([200, 304, 302, 404, 301, 401, 403, 206, 444, 400, 408, 405])].resample(t_span, how='count')
fail_df = df[df['Status'].isin([502, 499, 504, 500, 444])].resample(t_span, how='count')
success_df.plot(label="Success")
fail_df.plot(label="Failure")
legend()

# %% [markdown]
# Those are the requests served by nginx, so it includes both static files like css and javascript and dynamic content that was passed off to the Django app running on uwsgi. Let's filter out the static files and see how uwsgi did. In this case almost all of the static files have `/static/` in the path with a few exceptions such as the `favicon.ico`.

# %%
dynamic_df = df[df['Request'].str.contains(r'^GET /(static|favicon.ico)') == False]
dynamic_df[0:10]
# Out:
#                      Status  \
# Time
# 2015-02-15 02:38:25     200
# 2015-02-15 02:38:28     200
# 2015-02-15 02:38:33     200
# 2015-02-15 02:38:45     303
# 2015-02-15 02:38:47     200
# 2015-02-15 02:38:54     200
# 2015-02-15 02:39:00     200
# 2015-02-15 02:39:07     200
# 2015-02-15 02:39:07     303
# 2015-02-15 02:39:09     200
#
#                             b  \
# Time
# 2015-02-15 02:38:25  0.003828
# 2015-02-15 02:38:28  0.002899
# 2015-02-15 02:38:33  0.002631
# 2015-02-15 02:38:45  0.000559
# 2015-02-15 02:38:47  0.002653
# 2015-02-15 02:38:54  0.002964
# 2015-02-15 02:39:00  0.002527
# 2015-02-15 02:39:07  0.002581
# 2015-02-15 02:39:07  0.000559
# 2015-02-15 02:39:09  0.002909
#
#                                                                Request  \
# Time
# 2015-02-15 02:38:25                         GET /home/plugger HTTP/1.1
# 2015-02-15 02:38:28               GET /profile/14119369/inbox HTTP/1.1
# 2015-02-15 02:38:33  GET /conversaciones/b21cd7b79c0d079a92db4486e9...
# 2015-02-15 02:38:45  POST /conversaciones/b21cd7b79c0d079a92db4486e...
# 2015-02-15 02:38:47  GET /conversaciones/b21cd7b79c0d079a92db4486e9...
# 2015-02-15 02:38:54               GET /profile/14119369/inbox HTTP/1.1
# 2015-02-15 02:39:00  GET /conversaciones/bdf5e89ad35b5a36c7d1818094...
# 2015-02-15 02:39:07  GET /conversaciones/bdf5e89ad35b5a36c7d1818094...
# 2015-02-15 02:39:07  POST /conversaciones/bdf5e89ad35b5a36c7d181809...
# 2015-02-15 02:39:09               GET /profile/14119369/inbox HTTP/1.1
#
#                            msisdn
# Time
# 2015-02-15 02:38:25  526142530854
# 2015-02-15 02:38:28  526142530854
# 2015-02-15 02:38:33  526142530854
# 2015-02-15 02:38:45  526142530854
# 2015-02-15 02:38:47  526142530854
# 2015-02-15 02:38:54  526142530854
# 2015-02-15 02:39:00  526142530854
# 2015-02-15 02:39:07  526142530854
# 2015-02-15 02:39:07  526142530854
# 2015-02-15 02:39:09  526142530854

# %%
by_msisdn =

# %%
success_df = dynamic_df[dynamic_df['Status'].isin([200, 304, 302, 301, 401])].resample(t_span, how='count')
fail_df = dynamic_df[dynamic_df['Status'].isin([502, 499, 504, 500])].resample(t_span, how='count')
success_df.plot(label="Success", color="g")
fail_df.plot(label="Failure", color="r")
legend()

# %% [markdown]
# Ouch! So during the initial peak, uwsgi is failing more often than not. Let's look at the same data in a stacked bar chart.

# %%
responses_df = DataFrame({'Success': success_df, 
                          'Failure': fail_df,
                          })
responses_df.plot(kind="bar", stacked=True, xticks=(), colors=("r", "g",))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c52d487dd6f0> in <module>()
#       1 responses_df = DataFrame({'Success': success_df,
# ----> 2                           'Failure': fail_df,
#       3                           })
#       4 responses_df.plot(kind="bar", stacked=True, xticks=(), colors=("r", "g",))
#
# /Users/Nicolas/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     206                                  dtype=dtype, copy=copy)
#     207         elif isinstance(data, dict):
# --> 208             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     209         elif isinstance(data, ma.MaskedArray):
#     210             import numpy.ma.mrecords as mrecords
#
# /Users/Nicolas/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     334
#     335         return _arrays_to_mgr(arrays, data_names, index, columns,
# --> 336                               dtype=dtype)
#     337
#     338     def _init_ndarray(self, values, index, columns, dtype=None,
#
# /Users/Nicolas/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    4615     # figure out the index, if necessary
#    4616     if index is None:
# -> 4617         index = extract_index(arrays)
#    4618     else:
#    4619         index = _ensure_index(index)
#
# /Users/Nicolas/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in extract_index(data)
#    4654
#    4655         if not indexes and not raw_lengths:
# -> 4656             raise ValueError('If using all scalar values, you must pass'
#    4657                              ' an index')
#    4658
#
# ValueError: If using all scalar values, you must pass an index

# %% [markdown]
# It looks like about 2,000 requests / hour is all uwsgi can handle before it starts to throw errors. That is only about 1 request every two seconds so that is a pretty big problem.
#
# We needed to handle 10,000 requests / hour, but we were only able to handle 2,000 requests / hour. So it looks like we would need roughly 5x the capacity to handle a spike of this size. This is a little bit misleading though because many visitors abandoned the site after hitting 50X errors and long page loads.
#
# Here is a view of the same traffic spike from Google Analytics.
#
# ![Google Analytics Pageviews vs. Pages per Visit](files/data/google-analytics.png)
#
# During the spike, pages per visit were roughly half of what they normally were, so let's double the 5x estimate and plan for 10x the capacity to handle this load.

# %% [markdown]
# ## Solutions

# %% [markdown]
# One solution is to upgrade the server running uwsgi and use ten times the number of workers to handle requests, but let's see if we can be a bit smarter.
#
# Another solution is to optimize the web app by shortening long-running requests, but I have already picked most of the low hanging fruit there.
#
# Let's investigate to see if there are any opportunities to prevent requests from hitting uwsgi in the first place.
#
# First let's get a count pages with the most requests.

# %%
dynamic_df['Request'].value_counts().head(40)
# Out:
# GET /profile/14119369/inbox HTTP/1.1                            1471
# GET /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1     340
# GET /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1     251
# GET /home/plugger HTTP/1.1                                       184
# POST /conversaciones/08ba535fae7c22ebdb6e23185ceefbec HTTP/1.1     155
# POST /conversaciones/838f14e41b7d8b7cf8f70fd193a74735 HTTP/1.1     121
# GET /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1     112
# GET /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1     108
# GET /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1      72
# GET /friends/ HTTP/1.1                                            69
# GET /conversaciones/459ba39ccd05173517b155fc1d4855d7 HTTP/1.1      68
# POST /conversaciones/94f4fa1bf6054302db63cab68a39bf7e HTTP/1.1      55
# GET /profile/14119369/activities/plugger HTTP/1.1                 54
# POST /conversaciones/1d428c0b116804c32b611c863cff66c6 HTTP/1.1      53
# GET /conversaciones/3a87cb8150487667d74cc94edf3d998f HTTP/1.1      52
# GET /conversaciones/70d4b27bf9599d49908ebf962eb2d60e HTTP/1.1      49
# GET /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1      44
# GET /conversaciones/547d0ff7648f5f194f2c827eccc8dd1d HTTP/1.1      44
# GET /conversaciones/2f38a17cf882ef80c8c10c85a688f882 HTTP/1.1      42
# GET /profile/12893395 HTTP/1.1                                    42
# GET /conversaciones/675edc0f82fe392d4527ad83ed6ad73e HTTP/1.1      40
# GET /friends/requests/ HTTP/1.1                                   39
# GET /conversaciones/5d5d472247e399dc949cb073ecadeba8 HTTP/1.1      38
# GET /profile/12893395/info HTTP/1.1                               38
# GET /conversaciones/bdf5e89ad35b5a36c7d18180946ab2e6 HTTP/1.1      36
# GET /conversaciones/cd0895b2dd0fa2f01570d3b782e2d13b HTTP/1.1      36
# POST /conversaciones/b3e3f6e478c5d1fdb63b72b391462623 HTTP/1.1      34
# GET /conversaciones/2a8d0bdd1b8b684898e844a8fa318c82 HTTP/1.1      34
# GET /conversaciones/e57029d43bba8dae20f5aecca7ec4687 HTTP/1.1      33
# GET /conversaciones/6c601af5cc7bdcfbc456f4ede32a6c35 HTTP/1.1      33
# POST /conversaciones/459ba39ccd05173517b155fc1d4855d7 HTTP/1.1      32
# GET /profile/15230785/info HTTP/1.1                               31
# GET /profile/14119369/media HTTP/1.1                              31
# GET /profile/15230785 HTTP/1.1                                    28
# POST /conversaciones/3a87cb8150487667d74cc94edf3d998f HTTP/1.1      25
# POST /conversaciones/547d0ff7648f5f194f2c827eccc8dd1d HTTP/1.1      22
# GET /conversaciones/281693ca3dcafabf1925cfb0305a5ec3 HTTP/1.1      21
# POST /conversaciones/2f38a17cf882ef80c8c10c85a688f882 HTTP/1.1      21
# POST /conversaciones/b21cd7b79c0d079a92db4486e95fc2d5 HTTP/1.1      21
# GET /profile/14119369/inbox?page=2&ajax HTTP/1.1                  21
# dtype: int64

# %% [markdown]
# There isn't much that can be done with the POST requests - they need to hit uwsgi so we can save new accounts or ratings in the database. So let's move on to the GET requests. There are two basic techniques for having nginx serve these pages. First, we could have uwsgi store the fully rendered page in memcached or similar, then have nginx try to pull the page from memcached and falling back to uwsgi if the page wasn't in the cache. The second idea is to have uwsgi create a static file, and then let nginx serve that if it exists. Unfortunately, in this case both of those solutions are problematic. It is beyond the scope of this notebook to go into details (hopefully I will have a separate blog post on that soon), but the gist is that for most of these pages, the content changes depending on who is viewing them, so they can't readily be cached at the page level.
#
# The biggest gain would be to make the homepage static. The homepage will redirect to a user's recommended page if they are already logged in, but we could possibly detect logged in users with nginx via the http headers and only serve the static page to logged out visitors. Let's see what proportion of visitors who hit the homepage were logged in already.

# %%
dynamic_df[dynamic_df['Request'].str.contains('GET / HTTP/1.1')]['Status'].value_counts()
# Out:
# 303    8
# dtype: int64

# %% [markdown]
# Of the visitors who were able to access the homepage, (19331 / (3053 + 946 + 19331)) * 100 = 83% were logged out. So that nginx configuration change would have saved a bit more than 40,000 requests.
#
# Out of how many total?

# %%
dynamic_df.count()
# Out:
# Status     6771
# b          6771
# Request    6771
# msisdn     6771
# dtype: int64

# %% [markdown]
# So that change alone would offload 13% of uwsgi's request load to nginx. That's a good start.
#
# Another thing that jumps out is that `/apple-touch-icon.png` and `/apple-touch-icon-precomposed.png` don't actually exist have to be passed off to uwsgi before they 404. Setting up nginx to serve anything ending in `.png` will save some requests. Let's see if there are any other files like that.

# %%
dynamic_df[dynamic_df['Request'].str.contains(r'(png |xml |gif )')]['Request'].value_counts().head(10)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Let's see how many requests that will save.

# %%
dynamic_df[dynamic_df['Request'].str.contains(r'(png |xml |gif )')].count()
# Out:
# Status     0
# b          0
# Request    0
# msisdn     0
# dtype: int64

# %% [markdown]
# That is another 3.5% of requests.
#
# Between those two changes we will save 16.5% of requests from hitting uwsgi. It isn't enough to prevent the need for a server upgrade, but it does get us a bit closer.
