# %%
# %matplotlib inline
from matplotlib import rc
## use floating point division always (ie matlab, python 3.x)
from __future__ import division

#autoload magic. This improves workflow when we are debugging
# %load_ext autoreload

# %autoreload 2
#add the ability to use latex to render equations in the plots
#rc('text', usetex=True)
#not working because it can't find a .sty file.
import pandas as pd
import numpy as np
import datetime
import time

from code.user import Users

import code.dates as dates
#from code.dates import cohort_range, to_date
from code.cohort2 import   validated_cohort_range

import matplotlib.pyplot as plt
# this modifies matplotlib rc so we get a nicer style
pd.options.display.mpl_style = 'default' 

from IPython.html import widgets
from IPython.display import clear_output, display, HTML

from collections import OrderedDict
from code.engagement import Engagement

from pandas.tools.plotting import scatter_matrix

from sklearn.preprocessing import StandardScaler

# %%
#filenames for the two .csv files version 4 for the calendar year 2014 located in the data folder
sessions_fn = _rootdir+'data/sessions.a.csv'
users_fn = _rootdir+'data/users.a.csv'

# %%
#users dataframe #set nrows to None when finished developing
udf = pd.read_csv(users_fn,  index_col = 'user_id', nrows = None)

# %%
#sessions dataframe #set nrows to None when finished developing
start = time.time()
sdf = pd.read_csv(sessions_fn, index_col = 'user_id', nrows = None)
print 'time to load: {0:.2} minutes'.format((time.time()-start)/60)
# Out:
# time to load: 0.29 minutes

# %%
bad_df = pd.read_csv(_rootdir+'data/rg30_201412.a.csv', index_col = ['user_id'])

# %%
import random

rows=random.sample(bad_df.index, 20000)
sample=bad_df.ix[rows]
bad_df=sample.dropna()
#sample_fn='data/bad_df.csv'
#sample.to_csv(sample_fn)
#!open {sample_fn}

# %%
bad_udf = udf.ix[bad_df.index]
bad_sdf = sdf.ix[bad_df.index]

# %%
start = time.time()
users = Users( bad_udf, bad_sdf, date_str_to_period = True, fraction_of_population = 1, trial = True)
print 'time to create: {0:.2} minutes'.format((time.time()-start)/60)
# Out:
# users table size (20000, 15)
# sessions table size (822991, 21)
# size of sessions data set after intersection (0, 21) with 0 users remaining.
# most recent "last seen" date, nan and the most recent session date, nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e05eeb272078> in <module>()
#       1 start = time.time()
# ----> 2 users = Users( bad_udf, bad_sdf, date_str_to_period = True, fraction_of_population = 1, trial = True)
#       3 print 'time to create: {0:.2} minutes'.format((time.time()-start)/60)
#
# /Users/nicolas/dev/pmx/code/user.pyc in __init__(self, udf, sdf, validate_dfs, date_str_to_period, fraction_of_population, trial)
#      84         #slice on from the first session to the last session
#      85         self.total_daily_users = total_daily_users[sdf.time.min():
# ---> 86                                                    sdf.time.max()]
#      87         #short name for daily users
#      88         tdu = self.total_daily_users
#
# /Users/nicolas/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     547             key = _check_bool_indexer(self.index, key)
#     548
# --> 549         return self._get_with(key)
#     550
#     551     def _get_with(self, key):
#
# /Users/nicolas/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _get_with(self, key)
#     552         # other: fancy integer or otherwise
#     553         if isinstance(key, slice):
# --> 554             indexer = self.index._convert_slice_indexer(key, typ='getitem')
#     555             return self._get_values(indexer)
#     556         elif isinstance(key, ABCDataFrame):
#
# /Users/nicolas/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in _convert_slice_indexer(self, key, typ)
#     702
#     703             return True
# --> 704         self._validate_slicer(key, validate)
#     705
#     706         # figure out if this is a positional indexer
#
# /Users/nicolas/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in _validate_slicer(self, key, f)
#     657         for c in ['start','stop','step']:
#     658             if not f(getattr(key,c)):
# --> 659                 self._convert_indexer_error(key.start, 'slice {0} value'.format(c))
#     660
#     661     def _convert_slice_indexer_getitem(self, key, is_index_slice=False):
#
# /Users/nicolas/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in _convert_indexer_error(self, key, msg)
#     781             msg = 'label'
#     782         raise TypeError("the {0} [{1}] is not a proper indexer for this index "
# --> 783                         "type ({2})".format(msg, key, self.__class__.__name__))
#     784
#     785     def get_duplicates(self):
#
# TypeError: the slice start value [nan] is not a proper indexer for this index type (Index)

# %%
users.udf.retention_index.head()
# Out:
# user_id
# ad6e0f10918d    0.947368
# 6c4e013681aa    0.985604
# 056b5d35bbbc    1.000000
# e86a5c52ae36    0.974104
# 3561308e4acf    1.000000
# Name: retention_index, dtype: float64

# %%
bad2_udf = users.get_info(users.udf.copy(), units = 'seconds')

# %%
bad_df['rankT'] = bad_df['rankA']+bad_df['rankB']

# %%
bad_df = bad_df.sort(columns = ['rankT', 'rankB'])

# %%
len(set(bad_df.index).intersection(udf.index))
# Out:
# 10000

# %%
bad2_udf.to_csv(_rootdir+'data/validated_joined_rg_2015-02-11_users.a.csv')

# %%
bad2_udf.ix[bad_df.tail(10).index]
# Out:
#                   joined   last_seen  disk_usage  state  friends  invites  \
# user_id
# 2b3352d61491  2014-06-08  2015-01-10           0      1     2123       40
# 9c4daf629c20  2014-01-19  2015-01-10      422414      1      198       16
# df42665c8e63  2014-07-07  2015-01-10           0      1      550       98
# 4c2a69891e4b  2014-04-13  2015-01-10      443330      1      987      383
# 3dc68d44ddbb  2014-02-11  2015-01-10   929815026      1     1963      199
# af5b7a6620d0  2014-01-07  2015-01-08           0      1     1291      247
# 5c598a06cc7b  2013-10-26  2015-01-10    29083678      1     2202      782
# 9f2c70e977f3  2013-10-08  2015-01-10       37872      1       89      107
# 33c663aa32a7  2014-01-16  2015-01-10    32785634      1     4009        4
# e2e6bbaba100  2013-10-27  2015-01-10       24804      1      243       51
#
#               rcvdInv  rejectd  sim  twFrs          ...               help  \
# user_id                                             ...
# 2b3352d61491        1        4    0      0          ...           0.019355
# 9c4daf629c20        0        7    0      0          ...           0.019737
# df42665c8e63        2        2    0      0          ...           0.063291
# 4c2a69891e4b        0        0    0      0          ...           0.019481
# 3dc68d44ddbb        0      113    0      0          ...           0.030675
# af5b7a6620d0        1        5    0      0          ...           0.007937
# 5c598a06cc7b        1       31    0      0          ...           0.036810
# 9f2c70e977f3        0        6    0      0          ...           0.128571
# 33c663aa32a7        2      336    0      0          ...           0.044304
# e2e6bbaba100        0       16    0      0          ...           0.062893
#
#                    mymed       conve      media     uploa     avata  \
# user_id
# 2b3352d61491  295.316129  329.225806  48.432258  1.967742  0.348387
# 9c4daf629c20   56.322368    2.684211  47.065789  0.085526  0.013158
# df42665c8e63   69.759494   50.063291  43.734177  3.025316  0.177215
# 4c2a69891e4b   98.590909  105.915584  87.876623  2.675325  0.142857
# 3dc68d44ddbb  127.337423  267.981595  75.521472  7.184049  0.515337
# af5b7a6620d0  108.738095  157.365079  83.595238  0.222222  0.000000
# 5c598a06cc7b  111.957055  790.901840  60.809816  3.993865  0.239264
# 9f2c70e977f3   43.957143   11.542857  25.021429  0.364286  0.157143
# 33c663aa32a7  188.234177   97.259494  68.829114  1.474684  0.196203
# e2e6bbaba100   34.911950   27.566038  22.566038  0.767296  0.012579
#
#                    activ     publi  session_duration  user_engagement_rate
# user_id
# 2b3352d61491  195.574194  0.032258      36051.496774          36051.496774
# 9c4daf629c20   35.914474  0.019737       4525.467105           4525.467105
# df42665c8e63   43.430380  0.189873      17977.924051          17977.924051
# 4c2a69891e4b   89.409091  0.357143      25761.759740          25761.759740
# 3dc68d44ddbb  140.993865  0.613497      35243.736196          35243.736196
# af5b7a6620d0   69.976190  0.277778      20454.785714          20343.618401
# 5c598a06cc7b  134.631902  0.687117      48271.656442          48271.656442
# 9f2c70e977f3   18.585714  0.035714       5893.550000           5893.550000
# 33c663aa32a7  146.386076  0.556962      15392.772152          15392.772152
# e2e6bbaba100   54.345912  0.232704      13434.484277          13434.484277
#
# [10 rows x 37 columns]

# %%
columns_to_convert = ['joined', 'last_seen']
    
    
#convert datetime like strings to period objects (date only)
udf = dates.to_date(dates.to_datetime(udf, columns = columns_to_convert
                                     ).dropna(subset=['last_seen']), 
                    columns = columns_to_convert)

# %%
del bad2_udf['state']

# %%
del bad2_udf['pi']

# %%
del bad2_udf['yt']

# %%
bad2_udf['age'] = bad2_udf['last_seen']- bad2_udf['joined']
most_recent_last_seen_date = bad2_udf.last_seen.max()

#candidate for churn 
bad2_udf['dust'] = (most_recent_last_seen_date - 
                    bad2_udf.last_seen) 
bad2_udf.columns
# Out:
# Index([u'joined', u'last_seen', u'disk_usage', u'friends', u'invites', u'rcvdInv', u'rejectd', u'sim', u'twFrs', u'fbFrs', u'fk', u'area', u'trial', u'retention_index', u'activity_level', u'sessions_per', u'average_session_duration', u'duration', u'pv', u'variety', u'inbox', u'home', u'frien', u'info', u'help', u'mymed', u'conve', u'media', u'uploa', u'avata', u'activ', u'publi', u'session_duration', u'user_engagement_rate', u'age', u'dust'], dtype='object')

# %%
bad3_udf = bad2_udf[[u'user_engagement_rate', 'variety', u'sessions_per', 'activ', u'pv', 'dust',
                     u'info', 'friends', 'frien', 'twFrs', 'fbFrs', 'rejectd']].fillna(0).rank(method = 'min')

# %%
judf = bad3_udf.join(bad_df).fillna(-1)

# %%
plt.hist(judf.rankT, bins = 10)
print ''

# %%
judf = judf[judf.dust < 2]

# %%
scatter_matrix(judf, figsize = (20,16))
print ''

# %%
plt.hist(judf.rankT, bins = 10)
print ''

# %%
scatter_matrix(judf, figsize = (20,16))
print ''

# %%
from sklearn import decomposition
from sklearn.preprocessing import StandardScaler

# %%
pca_df = judf[judf.columns[:-4]]

# %%
scaler = StandardScaler()
X = scaler.fit_transform(pca_df.values)#scale X

# %%
pca = decomposition.PCA(n_components=5, whiten = True)

pca.fit(X)
Xt = pca.transform(X)
pca.explained_variance_
# Out:
# array([ 5.97462237,  1.32852217,  0.93507288,  0.72045941,  0.30394686])

# %%
from code.clustering import scatter3d

# %%
colors = scaler.fit_transform(10*(judf.rankT.values/10.).astype(int))

# %%
scatter3d(x= Xt[:,0], y= Xt[:,1], z= Xt[:,2], labels = colors)
